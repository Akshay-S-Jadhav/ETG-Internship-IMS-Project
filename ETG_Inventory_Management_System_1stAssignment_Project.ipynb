# %%
import time
import json

Elec_device_record = { 101 : {"Device Type":"Laptop","Company": "HP" ,"Model Name":"HP 15s", "RAM": "8", "ROM" :"1TB HDD+256GB SSD", "Price": 65000 , "Stock": 5},
                       102 : {"Device Type":"Laptop","Company": "HP" ,"Model Name":"HP 14s" , "RAM": "8", "ROM" :"512GB SSD", "Price": 62000,"Stock": 7},
                       103 : {"Device Type":"Laptop","Company": "HP" ,"Model Name":"HP 360x", "RAM": "8", "ROM" :"1TB HDD+256GB SSD", "Price": 69000,"Stock": 7},
                       104 : {"Device Type":"Laptop","Company": "HP" ,"Model Name":"HP Omen5x", "RAM": "16", "ROM" :"1TB SSD", "Price": 85000,"Stock": 4},
                       105 : {"Device Type":"Laptop","Company": "Asus" ,"Model Name":"vivobook 14x", "RAM": "8", "ROM" :"1TB HDD", "Price": 40000,"Stock": 6},
                       106 : {"Device Type":"Laptop","Company": "Asus" ,"Model Name":"vivobook 15x", "RAM": "8", "ROM" :"1TB HDD+256GB SSD", "Price": 58000,"Stock": 5},
                       107 : {"Device Type":"Laptop","Company": "Asus" ,"Model Name":"TUF Gaming 15.6", "RAM": "8", "ROM" : "512GB SSD", "Price": 56000,"Stock": 6},
                       108 : {"Device Type":"Laptop","Company": "Asus" ,"Model Name":"TUF Gaming 17.3", "RAM": "16", "ROM" :"1TB HDD+256GB SSD", "Price": 72000,"Stock": 8},
                       109 : {"Device Type":"Laptop","Company": "Asus" ,"Model Name":"ROG Strix GT", "RAM": "8", "ROM" :"1TB HDD+256GB SSD", "Price": 75000,"Stock": 6},
                       110 : {"Device Type":"Laptop","Company": "Asus" ,"Model Name":"ROG Strix GTX", "RAM": "16", "ROM" :"1TB HDD+512GB SSD", "Price": 88000,"Stock": 7},
                       111 : {"Device Type":"Laptop","Company": "DELL" ,"Model Name":"Vostro V1", "RAM": "8", "ROM" :"512GB SSD", "Price": 57000,"Stock": 7},
                       112 : {"Device Type":"Laptop","Company": "DELL" ,"Model Name":"Vostro V5", "RAM": "8", "ROM" :"1TB HDD+256GB SSD", "Price": 59000,"Stock": 4},
                       113 : {"Device Type":"Laptop","Company": "DELL" ,"Model Name":"Inspiron RX", "RAM": "8", "ROM" :"512GB SSD", "Price": 67000,"Stock": 2},
                       114 : {"Device Type":"Laptop","Company": "DELL" ,"Model Name":"Inspiron RX5", "RAM": "8", "ROM" :"1TB HDD+256GB SSD", "Price": 77000,"Stock": 4},
                       115 : {"Device Type":"Laptop","Company": "Apple" ,"Model Name":"Macbook 14", "RAM": "8", "ROM" :"512GB SSD", "Price": 70000,"Stock": 6},
                       116 : {"Device Type":"Laptop","Company": "Apple" ,"Model Name":"Macbook 15", "RAM": "8", "ROM" :"1TB SSD", "Price": 98000,"Stock": 3},
                       117 : {"Device Type":"Mobile","Company": "OnePlus" ,"Model Name":"Elite", "RAM": "6", "ROM" :"128GB", "Price": 35000,"Stock": 12},
                       118 : {"Device Type":"Mobile","Company": "Realme" ,"Model Name":"R21", "RAM": "6", "ROM" :"128GB", "Price": 21000,"Stock": 15},
                       119 : {"Device Type":"Mobile","Company": "Redmi" ,"Model Name":"Note 9 pro", "RAM": "6", "ROM" :"128GB", "Price": 24000,"Stock": 9},
                       120 : {"Device Type":"Mobile","Company": "Samsung" ,"Model Name":"S51", "RAM": "8", "ROM" :"128GB", "Price": 46000,"Stock": 8},
  
                       121 : {"Device Type": "Mobile", "Company": "LYF", "Model Name": "Jio Phone", "RAM": "1", "ROM": "4GB", "Price": 1500, "Stock": 12}, 
                       122 : {"Device Type": "Mobile", "Company": "Realme ", "Model Name": "realme C11 ", "RAM": "2", "ROM": "32", "Price": 7000, "Stock": 4}, 
                       123 : {"Device Type": "Laptop", "Company": "Acer", "Model Name": "Acer One 14", "RAM": "4", "ROM": "1TB HDD", "Price": 23990, "Stock": 4}, 
                       124 : {"Device Type": "Laptop", "Company": "Acer", "Model Name": "Acer Aspire Switch One", "RAM": "2", "ROM": "32GB SSD", "Price": 13899, "Stock": 4}, 
                       125 : {"Device Type": "Laptop", "Company": "Lenovo", "Model Name": "Lenovo Ideapad S145", "RAM": "4", "ROM": "1TB HDD", "Price": 28000, "Stock": 4}, 
                       126 : {"Device Type": "Laptop", "Company": "Acer", "Model Name": "Acer Swift 3 SF", "RAM": "8", "ROM": "512GB SSD", "Price": 82793, "Stock": 6}, 
                       127 : {"Device Type": "Mobile", "Company": "Vivo", "Model Name": "Vivo Y73", "RAM": "8", "ROM": "128GB", "Price": 20990, "Stock": 4}, 
                       128 : {"Device Type": "Mobile", "Company": "Samsung", "Model Name": "Galaxy M02s", "RAM": "4", "ROM": "64GB", "Price": 10499, "Stock": 4}, 
                       129 : {"Device Type": "Mobile", "Company": "Redmi", "Model Name": "Note 10", "RAM": "4", "ROM": "64GB", "Price": 13999, "Stock": 4}, 
                       130 : {"Device Type": "Mobile", "Company": "Realme", "Model Name": "realme C20", "RAM": "4", "ROM": "64GB", "Price": 9000, "Stock": 4}
                     } 

js = json.dumps(Elec_device_record)

fd = open("Elec_device_record.json",'w')
fd.write(js)
fd.close()

fd = open("Elec_device_record.json",'r')
txt = fd.read()
fd.close()

Elec_device_record = json.loads(txt)

def addRecord(id):
    """
      Here we will add new items in record
    """
    add=input("Do you want to add new record Y/N  ").lower()
    if add=='y':
        Elec_device_record[id]={}
        dtype=input("Enter device type  ")
        com=input("Enter company name   ")
        model=input("Enter Model Name  ")
        ram=input("enter ram")
        rom=input("enter rom")
        price=input("enter price")
        stock=input("enter stock")
        
       
        Elec_device_record[id]['Device type']=dtype
        Elec_device_record[id]['Company']=com
        Elec_device_record[id]['Model Name']=model
        Elec_device_record[id]['RAM']=ram
        Elec_device_record[id]['ROM']=rom
        Elec_device_record[id]['Price']=price
        Elec_device_record[id]['Stock']=stock
       
        print("Record added successfully  ")
    else:
        print("Operation Canceled  ")


def purchase():
            print("___________________________________________________________")
            ui_prod = input("Enter The Product ID Which you want to Buy :  ")
            ui_quan = input("Enter How much item do you want            :  ")

            print("Product Specifications are as follows for your Provided ID")
            print("___________________________________________________________")
            print("Product Type:",Elec_device_record[ui_prod]['Device Type'])
            print("Company:",Elec_device_record[ui_prod]['Company'])
            print("Model Name:",Elec_device_record[ui_prod]['Model Name'])
            print("RAM:",Elec_device_record[ui_prod]['RAM'])
            print("ROM:",Elec_device_record[ui_prod]['ROM'])
            print("Price:",Elec_device_record[ui_prod]['Price'])
            print("Stock:",Elec_device_record[ui_prod]['Stock'])
            print("Purchase time:",time.ctime())
            print("___________________________________________________________")
            print("Total Amount to Pay:",int(Elec_device_record[ui_prod]['Price'])*int(ui_quan))
            print("___________________________________________________________")

            amt=int(Elec_device_record[ui_prod]['Price'])*int(ui_quan)


def discount():
    print("____________________________________________________________________")
    print("Check eligibility for Discount")
    print("____________________________________________________________________")

    ui_prod = input("Enter The Product ID Which you want to Buy :  ")
    ui_quan = input("Enter How much item do you want            :  ")
    amt=int(Elec_device_record[ui_prod]['Price'])*int(ui_quan)
    print("Amount:",amt)
    print("____________________________________________________________________")

    if(amt>=7000):
        print("Hooray!! You are eligible for the discount")
        if (amt>=120000):
            print("You have make a puchase of Amount greater than 120000\n")
            disc = amt*0.045
            print("You got Discount of :",disc)
            print("You need to pay :",amt-disc,"only.")
            print("Thank you for shoping ")
            print("____________________________________________________________________")

        elif (amt<120000 and amt>=70000):
            print("You have make a puchase of Amount greater than 70000\n")
            disc = amt*0.04
            print("You got Discount of :",disc)
            print("You need to pay :",amt-disc,"only")
            print("Thank you for shoping ")
            print("____________________________________________________________________")

        elif (amt<70000 and amt>=20000):
            print("You have make a puchase of Amount greater than 20000\n")
            disc = amt*0.035
            print("You got Discount of :",disc)
            print("You need to pay :",amt-disc,"only")
            print("Thank you for shoping ")
            print("____________________________________________________________________")

        else:
            print("You have make a puchase of Amount greater than 7000\n")
            disc = amt*0.03
            print("You got Discount of :",disc)
            print("You need to pay :",amt-disc,"only")
            print("Thank you for shoping ")
            print("____________________________________________________________________")

    else:
        print("____________________________________________________________________")
        print("Oops!!! You are not eligible for any discount")
        print("____________________________________________________________________")


def updatestock():
    ui_prod = input("Enter The Product ID Which you want to update by Adding or Removing :  ")
    print("Note : To add the Item please input integer with a negative value ")
    ui_quan = input("Enter How much Stock you want to update           :  ")
    update = int(Elec_device_record[ui_prod]['Stock']) - int(ui_quan)
    
    Elec_device_record[ui_prod]['Stock'] = update
    print("The Remaining Available Stock for ",Elec_device_record[ui_prod]['Model Name']," is :",update)
    #print("The Stock available is as follows")
    #print(Elec_device_record)


def main():
    print("====================================================================================\n")
    print("_________________Welcome to the Inventory Management System Project_________________\n")
    print("====================================================================================\n")
    print("---------------- Choose one of the following Option for Transaction-----------------\n")
    print(" 1 -> To view the List of items to purchase\n")
    print(" 2 -> To Add items in the list\n")
    print(" 3 -> To Make a Purchase \n")
    print(" 4 -> Check Eligibility for Discount\n")
    print(" 5 -> Update the Stock\n")
    
    ch = int(input("Enter Your choice : \n"))
    
    if ch == 1:
        print(Elec_device_record)
        print("___________________________________________________________________________________")
        anch = input("Want to make another choice, If Yes then type y or to quit type n :").lower()
        print("___________________________________________________________________________________")
        if anch == 'y':
            main()
        else:
            print(" ----------------------Please Visit Again, Have a Nice Day-------------------------")
            print(":)____________________________________Thank You!!_________________________________:)")
    elif ch == 2:
        addRecord(id)
        print("___________________________________________________________________________________")
        anch = input("Want to make another choice, If Yes then type y or to quit type n :").lower()
        print("___________________________________________________________________________________")
        if anch == 'y':
            main()
        else:
            print(" ----------------------Please Visit Again, Have a Nice Day-------------------------")
            print(":)____________________________________Thank You!!_________________________________:)")
    elif ch == 3:
        purchase()
        print("___________________________________________________________________________________")
        anch = input("Want to make another choice, If Yes then type y or to quit type n :").lower()
        print("___________________________________________________________________________________")
        if anch == 'y':
            main()
        else:
            print(" ----------------------Please Visit Again, Have a Nice Day-------------------------")
            print(":)____________________________________Thank You!!_________________________________:)")
    elif ch == 4:   
        discount()
        print("___________________________________________________________________________________")
        anch = input("Want to make another choice, If Yes then type y or to quit type n :").lower()
        print("___________________________________________________________________________________")
        if anch == 'y':
            main()
        else:
            print(" ----------------------Please Visit Again, Have a Nice Day-------------------------")
            print(":)____________________________________Thank You!!_________________________________:)")
    elif ch == 5:
        updatestock()
        print("___________________________________________________________________________________")
        anch = input("Want to make another choice, If Yes then type y or to quit type n :").lower()
        print("___________________________________________________________________________________")
        if anch == 'y':
            main()
        else:
            print(" ----------------------Please Visit Again, Have a Nice Day-------------------------")
            print(":)____________________________________Thank You!!_________________________________:)")
    else:
        print("Please Enter a valid Input")

main()
# Out:
# ...
#
# _________________Welcome to the Inventory Management System Project_________________
#
# ...
#
# ---------------- Choose one of the following Option for Transaction-----------------
#
#  1 -> To view the List of items to purchase
#
#  2 -> To Add items in the list
#
#  3 -> To Make a Purchase
#
#  4 -> Check Eligibility for Discount
#
#  5 -> Update the Stock
#
# Enter Your choice :
# 1
# ...
